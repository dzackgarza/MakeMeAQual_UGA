# %%
import yaml

with open(r'combined_questions.yaml') as file:
    qs = yaml.load(file)
# Out:
# /home/zack/gitclones/sage/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.

# %%
qs[0]
# Out:
# {'year': 2019,
#  'season': 'Fall',
#  'number': 1,
#  'exam': 'Algebra',
#  'university': 'UGA',
#  'tags': ['Groups', 'Conjugacy'],
#  'question': 'Let $G$ be a finite group with $n$ distinct conjugacy classes.\nLet $g_1 \\cdots g_n$ be representatives of the conjugacy classes of $G$.\n\nProve that if $g_i g_j = g_j g_i$ for all $i, j$ then $G$ is abelian.\n'}

# %%
Algebra_qs = [q for q in qs if q['exam'] == "Algebra"]
Real_qs = [q for q in qs if q['exam'] == "Real Analysis"]
Complex_qs = [q for q in qs if q['exam'] == "Complex_Analysis"]
Topology_qs = [q for q in qs if q['exam'] == "Topology"]

# %%
out_str = """---
title: Question Database
---

"""

out_str += f"# Algebra ({len(Algebra_qs)} Questions)\n"
out_str += "\n".join([f"\n**Question {i+1}**\n\n" + q['question'] for i, q in enumerate(Algebra_qs)])

out_str += f"# Real Analysis ({len(Real_qs)} Questions)\n"
out_str += "\n".join([f"\n**Question {i+1}**\n\n" + q['question'] for i, q in enumerate(Real_qs)])

out_str += f"# Complex Analysis ({len(Complex_qs)} Questions)\n"
out_str += "\n".join([f"\n**Question {i+1}**\n\n" + q['question'] for i, q in enumerate(Complex_qs)])

# %%
with open("temp.md", "w") as out_file:
    out_file.write(out_str)

# %%
len(Algebra_qs)
# Out:
# 140

# %%
Complex_qs
# Out:
# [{'year': 'Extra',
#   'number': 0,
#   'university': 'UGA',
#   'exam': 'Complex_Analysis',
#   'tags': ['Complex'],
#   'question': "(1) Assume $\\displaystyle f(z) = \\sum_{n=0}^\\infty c_n z^n$\nconverges in $|z| < R$. Show that for $r <R$,\n$$\\frac{1}{2 \\pi} \\int_0^{2 \\pi} |f(r e^{i \\theta})|^2 d \\theta =\n\\sum_{n=0}^\\infty |c_n|^2 r^{2n} \\; .$$\n\n(2) Deduce Liouville's theorem from (1).\n"},
#  {'year': 'Extra',
#   'number': 0,
#   'university': 'UGA',
#   'exam': 'Complex_Analysis',
#   'tags': ['Complex'],
#   'question': "Let $f$ be a continuous function in the region\n$$D=\\{z \\suchthat  \\abs{z}>R, 0\\leq \\arg z\\leq \\theta\\}\\quad\\text{where}\\quad\n1\\leq \\theta \\leq 2\\pi.$$ If there exists $k$ such that\n$\\displaystyle{\\lim_{z\\to\\infty} zf(z)=k}$ for $z$ in the region\n$D$. \nShow that $$\\lim_{R'\\to\\infty} \\int_{L} f(z) dz=i\\theta k,$$\nwhere $L$ is the part of the circle $|z|=R'$ which lies in the\nregion $D$.\n"},
#  {'year': 'Extra',
# ...
